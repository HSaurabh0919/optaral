# %% [markdown]
# # Optimizing delivery with Reinforcement Learning

# %% [markdown]
# ![](http://img.chefdentreprise.com/Img/BREVE/2018/3/328332/recette-nestor-atteindre-rentabilite-F.jpg)

# %%
# Base Data Science snippet
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tqdm import tqdm_notebook

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Environment definition
# As for any RL problem, an environment must be designed where the Agent will evolve.<br>
# For convenience and readability, we will define it like OpenAI Gym environments

# %%
# !pip3 install imageio
# Out:
# Collecting imageio
#   Using cached imageio-2.21.2-py3-none-any.whl (3.4 MB)
# Requirement already satisfied: numpy in /home/saurabh/.local/lib/python3.8/site-packages (from imageio) (1.22.0)
# Collecting pillow>=8.3.2
#   Downloading Pillow-9.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 1.0 MB/s eta 0:00:01
# Installing collected packages: pillow, imageio
# Successfully installed imageio-2.21.2 pillow-9.2.0

# %%
from delivery import *

# %%
env = DeliveryEnvironment(n_stops = 10)
# Out:
# Initialized Delivery Environment with 10 random stops
# Target metric for optimization is distance

# %%
env.render()

# %%
env.stops
# Out:
# [0]

# %%
for i in [0,1,2,3]:
    env.step(i)

# %%
env.render()

# %% [markdown]
# # Q Learning

# %%
import sys
sys.path.append("../")

from delivery import run_episode,DeliveryQAgent,run_n_episodes

# %% [markdown]
# ## Simple case

# %%
env = DeliveryEnvironment(n_stops = 500,method = "distance")
# Out:
# Initialized Delivery Environment with 500 random stops
# Target metric for optimization is distance

# %%
agent = DeliveryQAgent(env.observation_space,env.action_space)

# %%
run_n_episodes(env,agent,"training_500_stops.gif")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# (<delivery.DeliveryEnvironment at 0x7fa105135af0>,
#  <delivery.DeliveryQAgent at 0x7fa1059a35b0>)

# %% [markdown]
# ## Traffic case

# %%
env = DeliveryEnvironment(n_stops = 100,method = "traffic_box",box_size = 0.2,traffic_intensity = 100)
# Out:
# Initialized Delivery Environment with 100 random stops
# Target metric for optimization is traffic_box

# %%
agent = DeliveryQAgent(env.observation_space,env.action_space)

# %%
run_n_episodes(env,agent,"training_100_stops_traffic.gif")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# (<delivery.DeliveryEnvironment at 0x7fa0c91a76d0>,
#  <delivery.DeliveryQAgent at 0x7fa1050b3100>)

# %%
env.render()

# %%
fig = env.render(True)

# %%
from matplotlib import pyplot as plt

plt.savefig('connected_paths.png')
